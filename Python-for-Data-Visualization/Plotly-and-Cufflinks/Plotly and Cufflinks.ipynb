# %% [markdown]
# ### **No exercise was given in the lecture, this notebook is actually my note from the lecture**

# %%
import pandas as pd
import numpy as np

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df.head()
# Out:
#           A         B         C         D
# 0  1.015756 -0.467574 -0.011512 -1.604760
# 1 -0.516937 -1.159733  1.860296 -1.118959
# 2  0.445339  0.647405 -0.957491  0.799289
# 3  0.460311  1.176650  0.688375  0.050130
# 4  1.885531 -2.051146  0.722373  0.202232

# %% [markdown]
# ## **Line Plot**

# %%
df.iplot()
# Out:
# <div>                            <div id="17e3570b-686a-44ad-9f7e-cbb0ac8cdb9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Scatter Plot**

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div>                            <div id="08ffad46-75fa-406a-87b1-7acc139815ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Bar Plot**

# %%
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>                            <div id="2438214b-decd-46ee-ac6c-7ef1d7e32cd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="d1c82b7c-c9e5-4558-9869-2e42e59da48c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Box Plot**

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="83ac31d4-d0c7-4fa8-8665-b704145cb858" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='box')
# Out:
# <div>                            <div id="68c23ba7-bd0c-4b07-8ffb-5722f15536d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Surface Plot**

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>                            <div id="ab269f30-76e4-4549-a968-78aec6233a04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Histogram**
#
# Histogram with single column

# %%
df.A.iplot(kind='hist', bins=40)
# Out:
# <div>                            <div id="d5ccd16e-7db0-4b66-8d32-65739f3bed9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist', bins=30) #Histogram with multiple columns
# Out:
# <div>                            <div id="c2f9ab55-1e82-40b8-ad0e-09450b53219a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Spread Plot**

# %%
df[['A', 'B']].iplot(kind='spread')
# Out:
# c:\Users\HP - PC\AppData\Local\Programs\Python\Python310\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# c:\Users\HP - PC\AppData\Local\Programs\Python\Python310\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="a5976726-6d2d-4ec2-9a63-856f8c1cb919" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Bubble Plot**

# %%
df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>                            <div id="b3784602-0aca-4235-9f26-eef9b06417d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## **Scatter Matrix**

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="faa98054-09d5-456e-895f-9fa794e21400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
